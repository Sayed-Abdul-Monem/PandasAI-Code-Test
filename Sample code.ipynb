# %%
import os
import pandas as pd
from pandasai import Agent

#load the DataSet 
df = pd.read_csv("supermarket_sales.csv")


os.environ["PANDASAI_API_KEY"] = "put your api-key here"
agent = Agent(df)

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#Try
agent.chat("Calculate the total spent by each gender")
# Out:
#    Gender       Total
# 0  Female  167882.925
# 1    Male  155083.824

# %%
#Test
pd.DataFrame(df.groupby('Gender')['Total'].sum())
# Out:
#              Total
# Gender
# Female  167882.925
# Male    155083.824

# %%
#Try
agent.chat("Calculate the total spent on each product line by both the male and female gender")
# Out:
#     Gender            Product line       Total
# 0   Female  Electronic accessories  27102.0225
# 1   Female     Fashion accessories  30437.4000
# 2   Female      Food and beverages  33170.9175
# 3   Female       Health and beauty  18560.9865
# 4   Female      Home and lifestyle  30036.8775
# 5   Female       Sports and travel  28574.7210
# 6     Male  Electronic accessories  27235.5090
# 7     Male     Fashion accessories  23868.4950
# 8     Male      Food and beverages  22973.9265
# 9     Male       Health and beauty  30632.7525
# 10    Male      Home and lifestyle  23825.0355
# 11    Male       Sports and travel  26548.1055

# %%
#Test
pd.DataFrame(df.groupby(['Gender','Product line'])['Total'].sum())
# Out:
#                                     Total
# Gender Product line
# Female Electronic accessories  27102.0225
#        Fashion accessories     30437.4000
#        Food and beverages      33170.9175
#        Health and beauty       18560.9865
#        Home and lifestyle      30036.8775
#        Sports and travel       28574.7210
# Male   Electronic accessories  27235.5090
#        Fashion accessories     23868.4950
#        Food and beverages      22973.9265
#        Health and beauty       30632.7525
#        Home and lifestyle      23825.0355
#        Sports and travel       26548.1055

# %%
#Try
agent.chat("Try to create a barplot that shows how much money each gender spends on each product line")
# Out:
# 'C:/Users/sayed/Downloads/WO/Project/exports/charts/temp_chart.png'

# %%
#Try
agent.chat("Plot a barplot that shows the total spent by each gender")
# Out:
# Traceback (most recent call last):
#   File "C:\Users\sayed\anaconda3\Lib\site-packages\pandasai\pipelines\chat\generate_chat_pipeline.py", line 335, in run
#     ).run(input)
#       ^^^^^^^^^^
#   File "C:\Users\sayed\anaconda3\Lib\site-packages\pandasai\pipelines\pipeline.py", line 137, in run
#     raise e
#   File "C:\Users\sayed\anaconda3\Lib\site-packages\pandasai\pipelines\pipeline.py", line 101, in run
#     step_output = logic.execute(
#                   ^^^^^^^^^^^^^^
#   File "C:\Users\sayed\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 113, in execute
#     raise e
#   File "C:\Users\sayed\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sayed\anaconda3\Lib\site-packages\pandasai\pipelines\chat\code_execution.py", line 175, in execute_code
# ...
